# %% [markdown]
# The sequence.csv file was downloaded from NCBI and it contains information regarding all the complete SARS-CoV-2 genomes, without any ambigious characters, downloaded from NCBI.
# At first, we access it and remove those genomes that does not have a proper collection date.

# %%
import pandas as pd

def remove_genomes_with_no_collection_date(metadata_file):
    # Read the CSV file
    all_genomes_metadata_df = pd.read_csv(metadata_file)
    print("Initial number of genomes:",len(all_genomes_metadata_df))

    #Filter out data points that lacks proper collection dates
    all_genomes_metadata_df = all_genomes_metadata_df[(all_genomes_metadata_df['Collection_Date'].notna()) & 
            (all_genomes_metadata_df['Collection_Date'].str.len() >=7)]

    print("Number of genomes after filtering:",len(all_genomes_metadata_df))

    return all_genomes_metadata_df


metadata_file="../SARS-COV-2_Genomic_data/SARS-CoV-2_1063493_metadata.csv"
all_genomes_metadata_df=remove_genomes_with_no_collection_date(metadata_file)
# Out:
# /tmp/ipykernel_16479/4154533051.py:5: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   all_genomes_metadata_df = pd.read_csv(metadata_file)
# Initial number of genomes: 1063493
# Number of genomes after filtering: 1059141

# %% [markdown]
# We now sort the dataframe based on the collection dates of the genomes and remove the referece genome from the sampling population as we are going to add it later and use it as the outgroup for the tree construction

# %%
# Sort the DataFrame by Collection Date
all_genomes_metadata_df = all_genomes_metadata_df.sort_values('Collection_Date')

# Drop the row where 'Accession' is 'NC_045512.2'
all_genomes_metadata_df = all_genomes_metadata_df[all_genomes_metadata_df['Accession'] != 'NC_045512.2']

# %% [markdown]
# We sort the genomes based on their collection dates and shortlist time-wise evenly distributed genomes to be used in out study

# %%
def sample_genomes_timewise(all_genomes_metadata_df,n):
    # Sort the DataFrame based on the 'Collection_Date' column
    all_genomes_metadata_df_sorted = all_genomes_metadata_df.sort_values(by='Collection_Date')
    # Sample every nth row
    sampled_genomes_df = all_genomes_metadata_df_sorted.iloc[::n]

    return sampled_genomes_df

#select every nth sample from the sorted list
n=50
sampled_genomes_df=sample_genomes_timewise(all_genomes_metadata_df,n)

# %%
sampled_genomes_df
# Out:
#           Accession                                    Organism_Name  \
# 1063492  MN908947.3  Severe acute respiratory syndrome coronavirus 2
# 1063393  MT246667.1  Severe acute respiratory syndrome coronavirus 2
# 731870   OM403303.1  Severe acute respiratory syndrome coronavirus 2
# 1063448  MT123292.2  Severe acute respiratory syndrome coronavirus 2
# 928040   MT509662.1  Severe acute respiratory syndrome coronavirus 2
# ...             ...                                              ...
# 244      PQ237423.1  Severe acute respiratory syndrome coronavirus 2
# 494      PQ238425.1  Severe acute respiratory syndrome coronavirus 2
# 299      PQ237484.1  Severe acute respiratory syndrome coronavirus 2
# 376      PQ237580.1  Severe acute respiratory syndrome coronavirus 2
# 424      PQ237637.1  Severe acute respiratory syndrome coronavirus 2
#
#              Assembly                                         Submitters  \
# 1063492  set:MN908947  Wu,F., Zhao,S., Yu,B., Chen,Y.M., Wang,W., Son...
# 1063393  set:MT246667  Thornburg,N., Bradford,R., Rashid,S., Flores,B...
# 731870            NaN  Pui,K., Cheng,S., Gu,H., Poon,L., Peiris,M., C...
# 1063448  set:MT123292  Huang,J., Shi,Y., Sun,J., Zheng,K., Zhu,A., Su...
# 928040            NaN  Gruber,C.E., Rueca,M., Bartolini,B., Messina,F...
# ...               ...                                                ...
# 244               NaN  Howard,D., Batra,D., Cook,P.W., Caravas,J., Ra...
# 494               NaN  Reeb,V., Twait,E., Yakkos,A., Eveland,K., Benf...
# 299               NaN  Howard,D., Batra,D., Cook,P.W., Caravas,J., Ra...
# 376               NaN  Howard,D., Batra,D., Cook,P.W., Caravas,J., Ra...
# 424               NaN  Howard,D., Batra,D., Cook,P.W., Caravas,J., Ra...
#
#                                               Organization Org_location  \
# 1063492  Fudan University, Shanghai Public Health Clini...        China
# 1063393  US Food and Drug Administration, Center for De...          USA
# 731870   The University of Hong Kong, School of Public ...    Hong Kong
# 1063448  Guangzhou Customs, Technology Centre, Guangzho...        China
# 928040   INMI Lazzaro Spallanzani IRCCS, Laboratory of ...        Italy
# ...                                                    ...          ...
# 244      Centers for Disease Control and Prevention, Re...          USA
# 494          University of Iowa, State Hygienic Laboratory          USA
# 299      Centers for Disease Control and Prevention, Re...          USA
# 376      Centers for Disease Control and Prevention, Re...          USA
# 424      Centers for Disease Control and Prevention, Re...          USA
#
#         Release_Date   Pangolin                    PangoVersions  \
# 1063492   2020-01-12          B  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 1063393   2020-03-26          A  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 731870    2022-01-27          A  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 1063448   2020-02-28          B  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 928040    2021-06-30          B  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# ...              ...        ...                              ...
# 244       2024-08-27   KP.3.1.1  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 494       2024-08-27        NaN  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 299       2024-08-27     KP.2.9  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 376       2024-08-27  JN.1.11.1  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
# 424       2024-08-27   KP.3.1.1  4.3.1/1.29/v0.1.12/0.3.19/0.6.2
#
#         Surveillance_Sampling           Isolate  \
# 1063492                   NaN        Wuhan-Hu-1
# 1063393                   NaN           USA-WA1
# 731870                    NaN          Original
# 1063448                   NaN            IQTC04
# 928040                    NaN           INMI2-N
# ...                       ...               ...
# 244                      True  AZ-CDC-LC1115136
# 494                      True           2481404
# 299                      True  LA-CDC-LC1115430
# 376                      True  NC-CDC-LC1115487
# 424                      True  MD-CDC-LC1115041
#
#                                                    Species  Length  \
# 1063492  Severe acute respiratory syndrome-related coro...   29903
# 1063393  Severe acute respiratory syndrome-related coro...   29867
# 731870   Severe acute respiratory syndrome-related coro...   29851
# 1063448  Severe acute respiratory syndrome-related coro...   29923
# 928040   Severe acute respiratory syndrome-related coro...   29834
# ...                                                    ...     ...
# 244      Severe acute respiratory syndrome-related coro...   29688
# 494      Severe acute respiratory syndrome-related coro...   29756
# 299      Severe acute respiratory syndrome-related coro...   29691
# 376      Severe acute respiratory syndrome-related coro...   29598
# 424      Severe acute respiratory syndrome-related coro...   29692
#
#         Nuc_Completeness         Geo_Location    Country  USA          Host  \
# 1063492         complete                China      China  NaN  Homo sapiens
# 1063393         complete              USA: WA        USA   WA  Homo sapiens
# 731870          complete            Hong Kong  Hong Kong  NaN  Homo sapiens
# 1063448         complete     China: Guangzhou      China  NaN  Homo sapiens
# 928040          complete         Italy: Lazio      Italy  NaN  Homo sapiens
# ...                  ...                  ...        ...  ...           ...
# 244             complete         USA: Arizona        USA   AZ  Homo sapiens
# 494             complete            USA: Iowa        USA   IA  Homo sapiens
# 299             complete       USA: Louisiana        USA   LA  Homo sapiens
# 376             complete  USA: North Carolina        USA   NC  Homo sapiens
# 424             complete        USA: Maryland        USA   MD  Homo sapiens
#
#         Tissue_Specimen_Source Collection_Date
# 1063492                    NaN         2019-12
# 1063393         oronasopharynx      2020-01-19
# 731870                     NaN      2020-01-23
# 1063448   lung, oronasopharynx      2020-01-27
# 928040                     NaN      2020-01-30
# ...                        ...             ...
# 244             oronasopharynx      2024-08-13
# 494                        NaN      2024-08-13
# 299             oronasopharynx      2024-08-14
# 376             oronasopharynx      2024-08-16
# 424             oronasopharynx      2024-08-19
#
# [21183 rows x 20 columns]

# %% [markdown]
# We take these shortlisted genomes and subset the original fasta files contaitning all the genome sequences of SARS-CoV-2 to only contain these sequences

# %%
#We take the accessions of these samples
accessions = sampled_genomes_df['Accession'].tolist()

#We set the referemce genome as the first in the list
reference_id="NC_045512.2"
accessions = [reference_id] + accessions

from Bio import SeqIO
#Function to create the new multifasta file containing the sampled genome sequences
def filter_fasta(input_file, output_file, sequence_ids):
    # Open input FASTA file
    with open(input_file, "r") as input_handle:
        # Open output FASTA file
        with open(output_file, "w") as output_handle:
            # Iterate over each sequence in the input FASTA file
            for record in SeqIO.parse(input_handle, "fasta"):
                # Check if the sequence ID is in the provided list
                if record.id in sequence_ids:
                    #print(record.id)
                    # Write the sequence to the output FASTA file
                    SeqIO.write(record, output_handle, "fasta")

input_file = "../SARS-COV-2_Genomic_data/SARS-CoV-2_1063493_genomes.fasta"
output_file = f"SARS-CoV-2_{len(accessions)-1}+1.fasta"

filter_fasta(input_file, output_file, accessions)
