# %%
from modeller import *
from modeller.automodel import *

#from modeller import soap_protein_od

env = Environ()

env.io.atom_files_directory = ['basic-example/']  # Ensure the directory contains your PDB files


a = AutoModel(env, alnfile='basic-example/TvLDH-1bdmA.ali',
              knowns='1bdmA', sequence='TvLDH',
              assess_methods=(assess.DOPE,
                              #soap_protein_od.Scorer(),
                              assess.GA341))
a.starting_model = 1
a.ending_model = 5
a.make()
# Out:
# fndatmi_285W> Only      317 residues out of      318 contain atoms of type  CA
#               (This is usually caused by non-standard residues, such
#               as ligands, or by PDB files with missing atoms.)
# fndatmi_285W> Only      317 residues out of      318 contain atoms of type  CA
#               (This is usually caused by non-standard residues, such
#               as ligands, or by PDB files with missing atoms.)
#
# check_ali___> Checking the sequence-structure alignment.
#
# Implied intrachain target CA(i)-CA(i+1) distances longer than  8.0 angstroms:
#
# ALN_POS  TMPL  RID1  RID2  NAM1  NAM2     DIST
# ----------------------------------------------
# END OF TABLE
# read_to_681_> topology.submodel read from topology file:        3
# fndatmi_285W> Only      317 residues out of      318 contain atoms of type  CA
#               (This is usually caused by non-standard residues, such
#               as ligands, or by PDB files with missing atoms.)
# The following 1 residues contain 6-membered rings with poor geometries
# after transfer from templates. Rebuilding rings from internal coordinates:
#    <Residue 216:A (type TYR)>
# mdtrsr__446W> A potential that relies on one protein is used, yet you have at
#               least one known structure available. MDT, not library, potential is used.
# 0 atoms in HETATM/BLK residues constrained
# to protein atoms within 2.30 angstroms
# and protein CA atoms within 10.00 angstroms
# 0 atoms in residues without defined topology
# constrained to be rigid bodies
# condens_443_> Restraints marked for deletion were removed.
#               Total number of restraints before, now:    31013    28624
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  GLY:OXT  GLY
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   522031
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -37887.1797
#
#
#
#
# << end of ENERGY.
# DOPE score               : -37887.179688
# >> Model assessment by GA341 potential
#
# Surface library          : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/surf5.de
# Pair library             : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/pair9.de
# Chain identifier         : _
# % sequence identity      :    42.452999
# Sequence length          :          335
# Compactness              :     0.309438
# Native energy (pair)     :  -261.363469
# Native energy (surface)  :   -15.781768
# Native energy (combined) :    -7.899040
# Z score (pair)           :    -7.672644
# Z score (surface)        :    -7.073072
# Z score (combined)       :   -11.187737
# GA341 score              :     1.000000
#
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     5811
# Dynamic pairs routine                             : 2, NATM x NATM cell sorting
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        1757.4675
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :    2671       0      0   0.005   0.005      21.632       1.000
#  2 Bond angle potential               :    3625       0      5   1.953   1.953      273.74       1.000
#  3 Stereochemical cosine torsion poten:    1743       0     42  46.522  46.522      571.82       1.000
#  4 Stereochemical improper torsion pot:    1121       0      0   1.212   1.212      37.491       1.000
#  5 Soft-sphere overlap restraints     :    5811       0      0   0.003   0.003      5.0422       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :    6941       0      1   0.187   0.187      121.39       1.000
# 10 Distance restraints 2 (N-O)        :    6938       1     17   0.281   0.281      248.60       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:     334       0      2   4.584   4.584      82.080       1.000
# 14 Sidechain Chi_1 dihedral restraints:     279       0      0  72.633  72.633      63.208       1.000
# 15 Sidechain Chi_2 dihedral restraints:     214       0      2  69.188  69.188      72.864       1.000
# 16 Sidechain Chi_3 dihedral restraints:      84       0      1  86.064  86.064      63.562       1.000
# 17 Sidechain Chi_4 dihedral restraints:      32       0      0  84.597  84.597      20.094       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    3144       0      0   0.342   0.342      64.744       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:     333      25     31  24.565  48.939      27.309       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :    1165       0      3   0.659   0.659      83.894       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: TvLDH.V99990001
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   31670.8867
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 10                           : Distance restraints 2 (N-O)
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1  21935 205T 170L N   O    1564 1304   13.79   10.90    2.89    4.52   10.90    2.89    4.52
#
# -------------------------------------------------------------------------------------------------
#
# Feature 25                           : Phi/Psi pair of dihedral restraints
# List of the RVIOL violations larger than   :       6.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1
#    20        275N 275N N   CA   2113 2114 -164.39  137.00                   39.50
#    21   9452 292D 293K C   N    2248 2250   58.88   56.60   12.73    0.75  -62.90  138.93   24.27
#    21        293K 293K N   CA   2250 2251   26.07   38.60                  -40.80
#    22   9453 293K 294E C   N    2257 2259   54.03   54.60   31.58    2.38  -63.60  164.00   27.85
#    22        294E 294E N   CA   2259 2260   73.97   42.40                  -40.30
#    23   9489 329N 330H C   N    2563 2565  -49.35  -67.60   19.37    1.64  -63.20  171.76   20.64
#    23        330H 330H N   CA   2565 2566  146.50  140.00                  -42.30
#    24   9491 331L 332A C   N    2581 2583  -85.54  -68.20   42.35    3.96  -62.50  149.36   23.45
#    24        332A 332A N   CA   2583 2584  106.67  145.30                  -40.90
#    25   9492 332A 333Q C   N    2586 2588  -59.93  -73.00   35.82    2.11  -63.80  147.70   21.92
#    25        333Q 333Q N   CA   2588 2589  107.35  140.70                  -40.30
#
#
# report______> Distribution of short non-bonded contacts:
#
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     0    0    0    0    0   23   33  131  187  284  286  343  433  447  452
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  GLY:OXT  GLY
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   523439
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -38423.5156
#
#
#
#
# << end of ENERGY.
# DOPE score               : -38423.515625
# >> Model assessment by GA341 potential
#
# Surface library          : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/surf5.de
# Pair library             : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/pair9.de
# Chain identifier         : _
# % sequence identity      :    42.452999
# Sequence length          :          335
# Compactness              :     0.350223
# Native energy (pair)     :  -257.956973
# Native energy (surface)  :   -16.485023
# Native energy (combined) :    -7.973881
# Z score (pair)           :    -7.697435
# Z score (surface)        :    -7.034579
# Z score (combined)       :    -9.825519
# GA341 score              :     1.000000
#
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     5708
# Dynamic pairs routine                             : 2, NATM x NATM cell sorting
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        1657.3682
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :    2671       0      0   0.005   0.005      19.747       1.000
#  2 Bond angle potential               :    3625       0      3   1.899   1.899      258.41       1.000
#  3 Stereochemical cosine torsion poten:    1743       0     46  46.950  46.950      581.65       1.000
#  4 Stereochemical improper torsion pot:    1121       0      0   1.138   1.138      33.040       1.000
#  5 Soft-sphere overlap restraints     :    5708       0      0   0.003   0.003      4.4707       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :    6941       0      3   0.192   0.192      122.35       1.000
# 10 Distance restraints 2 (N-O)        :    6938       0      8   0.261   0.261      211.57       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:     334       0      1   3.971   3.971      61.427       1.000
# 14 Sidechain Chi_1 dihedral restraints:     279       0      0  67.881  67.881      51.184       1.000
# 15 Sidechain Chi_2 dihedral restraints:     214       0      1  75.737  75.737      81.107       1.000
# 16 Sidechain Chi_3 dihedral restraints:      84       0      0  68.566  68.566      48.861       1.000
# 17 Sidechain Chi_4 dihedral restraints:      32       0      0  75.617  75.617      18.337       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    3144       0      0   0.310   0.310      49.705       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:     333      25     31  26.340  47.468      49.713       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :    1165       0      0   0.612   0.612      65.807       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: TvLDH.V99990002
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   30382.5625
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 25                           : Phi/Psi pair of dihedral restraints
# List of the RVIOL violations larger than   :       6.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   9191  31G  32D C   N     225  227  -79.72  -96.50   71.17    3.00  -63.30   86.60    9.81
#     1         32D  32D N   CA    227  228   45.04  114.20                  -40.00
#     2   9249  89M  90P C   N     672  674  -73.86  -58.70   26.84    1.63  -64.50  155.83   12.13
#     2         90P  90P N   CA    674  675   -8.35  -30.50                  147.20
#     3   9251  91L  92K C   N     687  689 -102.21 -118.00   31.47    1.63  -62.90  157.85   22.82
#     3         92K  92K N   CA    689  690  166.33  139.10                  -40.80
#    22   9489 329N 330H C   N    2563 2565  -50.72  -67.60   17.09    1.36  -63.20  175.48   21.19
#    22        330H 330H N   CA   2565 2566  142.67  140.00                  -42.30
#    23   9490 330H 331L C   N    2573 2575  -61.19  -70.70   40.41    2.73  -63.50  143.54   20.06
#    23        331L 331L N   CA   2575 2576  102.32  141.60                  -41.20
#    24   9491 331L 332A C   N    2581 2583  120.88 -134.00  121.96    2.85  -62.50 -151.78   42.32
#    24        332A 332A N   CA   2583 2584 -151.18  147.00                  -40.90
#    25   9492 332A 333Q C   N    2586 2588 -127.80 -121.10   18.30    0.95  -63.80  175.08   22.97
#    25        333Q 333Q N   CA   2588 2589  122.66  139.70                  -40.30
#
#
# report______> Distribution of short non-bonded contacts:
#
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     0    0    0    0    1   16   42  141  177  249  275  326  419  436  416
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  GLY:OXT  GLY
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   522685
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -37810.3086
#
#
#
#
# << end of ENERGY.
# DOPE score               : -37810.308594
# >> Model assessment by GA341 potential
#
# Surface library          : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/surf5.de
# Pair library             : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/pair9.de
# Chain identifier         : _
# % sequence identity      :    42.452999
# Sequence length          :          335
# Compactness              :     0.322173
# Native energy (pair)     :  -274.322653
# Native energy (surface)  :   -13.537875
# Native energy (combined) :    -7.938921
# Z score (pair)           :    -7.664807
# Z score (surface)        :    -6.619422
# Z score (combined)       :    -9.405706
# GA341 score              :     1.000000
#
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     5770
# Dynamic pairs routine                             : 2, NATM x NATM cell sorting
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        1676.1266
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :    2671       0      0   0.005   0.005      17.399       1.000
#  2 Bond angle potential               :    3625       0      6   1.883   1.883      256.50       1.000
#  3 Stereochemical cosine torsion poten:    1743       0     41  46.288  46.288      566.36       1.000
#  4 Stereochemical improper torsion pot:    1121       0      0   1.185   1.185      34.957       1.000
#  5 Soft-sphere overlap restraints     :    5770       0      0   0.003   0.003      4.2668       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :    6941       0      3   0.193   0.193      121.30       1.000
# 10 Distance restraints 2 (N-O)        :    6938       1     10   0.284   0.284      235.85       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:     334       2      4   4.750   4.750      88.175       1.000
# 14 Sidechain Chi_1 dihedral restraints:     279       0      0  73.333  73.333      45.978       1.000
# 15 Sidechain Chi_2 dihedral restraints:     214       0      0  72.720  72.720      68.535       1.000
# 16 Sidechain Chi_3 dihedral restraints:      84       0      0  81.241  81.241      56.433       1.000
# 17 Sidechain Chi_4 dihedral restraints:      32       0      0  79.910  79.910      19.917       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    3144       0      0   0.312   0.312      49.864       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:     333      23     34  24.564  47.535      41.716       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :    1165       0      0   0.607   0.607      68.879       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: TvLDH.V99990003
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   30478.6016
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 13                           : Mainchain Omega dihedral restraints
# List of the RVIOL violations larger than   :       4.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   9536  43P  43P CA  C     325  329 -151.37 -180.00   28.63    5.72 -180.00   28.63    5.72
#
# -------------------------------------------------------------------------------------------------
#
# Feature 25                           : Phi/Psi pair of dihedral restraints
# List of the RVIOL violations larger than   :       6.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1   9191  31G  32D C   N     225  227  -77.77  -96.50   63.15    2.66  -63.30   95.00   10.92
#     1         32D  32D N   CA    227  228   53.89  114.20                  -40.00
#     2   9202  42I  43P C   N     322  324  -56.75  -64.50   24.18    2.22  -58.70  159.41   13.02
#     2         43P  43P N   CA    324  325  170.10  147.20                  -30.50
#     3   9203  43P  44P C   N     329  331  -13.44  -58.70   94.92   11.48  -58.70   94.92   11.48
#     3         44P  44P N   CA    331  332   52.93  -30.50                  -30.50
#     4   9251  91L  92K C   N     687  689 -135.21 -118.00   35.33    1.41  -62.90  165.84   25.86
#     4         92K  92K N   CA    689  690  169.96  139.10                  -40.80
#
#
# report______> Distribution of short non-bonded contacts:
#
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     0    0    0    0    0   24   28  152  195  270  267  351  428  436  407
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  GLY:OXT  GLY
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   521121
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -37872.6328
#
#
#
#
# << end of ENERGY.
# DOPE score               : -37872.632812
# >> Model assessment by GA341 potential
#
# Surface library          : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/surf5.de
# Pair library             : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/pair9.de
# Chain identifier         : _
# % sequence identity      :    42.452999
# Sequence length          :          335
# Compactness              :     0.337690
# Native energy (pair)     :  -258.587319
# Native energy (surface)  :   -15.230673
# Native energy (combined) :    -7.941218
# Z score (pair)           :    -8.143557
# Z score (surface)        :    -6.841018
# ...
#    18        294E 294E N   CA   2259 2260  100.61   42.40                  -40.30
#    19   9489 329N 330H C   N    2563 2565  -50.96  -67.60   16.86    1.18  -63.20 -179.99   23.28
#    19        330H 330H N   CA   2565 2566  137.29  140.00                  -42.30
#    20   9492 332A 333Q C   N    2586 2588  111.41   55.10  105.44   12.19  -63.80 -116.05   43.97
#    20        333Q 333Q N   CA   2588 2589  129.44   40.30                  -40.30
#
#
# report______> Distribution of short non-bonded contacts:
#
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     0    0    0    0    1   17   32  148  181  277  265  321  411  413  453
#
#
# << end of ENERGY.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# iupac_m_397W> Atoms were not swapped because of the uncertainty of how to handle the H atom.
# >> Model assessment by DOPE potential
# iatmcls_286W> MODEL atom not classified:  GLY:OXT  GLY
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):   517411
# Dynamic pairs routine                             : 1, NATM x NATM double loop
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        1    9999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :   15.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       F       F       F       T
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :      -38075.5859
#
#
#
#
# << end of ENERGY.
# DOPE score               : -38075.585938
# >> Model assessment by GA341 potential
#
# Surface library          : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/surf5.de
# Pair library             : /home/prittam-goswami/anaconda3/lib/modeller-10.5/modlib/pair9.de
# Chain identifier         : _
# % sequence identity      :    42.452999
# Sequence length          :          335
# Compactness              :     0.313524
# Native energy (pair)     :  -284.693459
# Native energy (surface)  :   -14.953235
# Native energy (combined) :    -8.491926
# Z score (pair)           :    -7.995277
# Z score (surface)        :    -6.973183
# Z score (combined)       :    -9.917729
# GA341 score              :     1.000000
#
#
#
# >> ENERGY; Differences between the model's features and restraints:
# Number of all residues in MODEL                   :      335
# Number of all, selected real atoms                :     2605    2605
# Number of all, selected pseudo atoms              :        0       0
# Number of all static, selected restraints         :    28624   28624
# COVALENT_CYS                                      :        F
# NONBONDED_SEL_ATOMS                               :        1
# Number of non-bonded pairs (excluding 1-2,1-3,1-4):     5630
# Dynamic pairs routine                             : 2, NATM x NATM cell sorting
# Atomic shift for contacts update (UPDATE_DYNAMIC) :    0.390
# LENNARD_JONES_SWITCH                              :    6.500   7.500
# COULOMB_JONES_SWITCH                              :    6.500   7.500
# RESIDUE_SPAN_RANGE                                :        0   99999
# NLOGN_USE                                         :       15
# CONTACT_SHELL                                     :    4.000
# DYNAMIC_PAIRS,_SPHERE,_COULOMB,_LENNARD,_MODELLER :        T       T       F       F       F
# SPHERE_STDV                                       :    0.050
# RADII_FACTOR                                      :    0.820
# Current energy                                    :        1604.1582
#
#
#
#
#
# Summary of the restraint violations:
#
#    NUM     ... number of restraints.
#    NUMVI   ... number of restraints with RVIOL > VIOL_REPORT_CUT[i].
#    RVIOL   ... relative difference from the best value.
#    NUMVP   ... number of restraints with -Ln(pdf) > VIOL_REPORT_CUT2[i].
#    RMS_1   ... RMS(feature, minimally_violated_basis_restraint, NUMB).
#    RMS_2   ... RMS(feature, best_value, NUMB).
#    MOL.PDF ... scaled contribution to -Ln(Molecular pdf).
#
#  #                     RESTRAINT_GROUP      NUM   NUMVI  NUMVP   RMS_1   RMS_2         MOL.PDF     S_i
# ------------------------------------------------------------------------------------------------------
#  1 Bond length potential              :    2671       0      0   0.005   0.005      18.596       1.000
#  2 Bond angle potential               :    3625       0      2   1.875   1.875      252.18       1.000
#  3 Stereochemical cosine torsion poten:    1743       0     44  46.640  46.640      572.63       1.000
#  4 Stereochemical improper torsion pot:    1121       0      0   1.161   1.161      33.121       1.000
#  5 Soft-sphere overlap restraints     :    5630       0      0   0.003   0.003      4.3767       1.000
#  6 Lennard-Jones 6-12 potential       :       0       0      0   0.000   0.000      0.0000       1.000
#  7 Coulomb point-point electrostatic p:       0       0      0   0.000   0.000      0.0000       1.000
#  8 H-bonding potential                :       0       0      0   0.000   0.000      0.0000       1.000
#  9 Distance restraints 1 (CA-CA)      :    6941       0      1   0.181   0.181      103.79       1.000
# 10 Distance restraints 2 (N-O)        :    6938       0      8   0.240   0.240      190.80       1.000
# 11 Mainchain Phi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 12 Mainchain Psi dihedral restraints  :       0       0      0   0.000   0.000      0.0000       1.000
# 13 Mainchain Omega dihedral restraints:     334       0      0   4.020   4.020      62.960       1.000
# 14 Sidechain Chi_1 dihedral restraints:     279       0      2  72.701  72.701      59.651       1.000
# 15 Sidechain Chi_2 dihedral restraints:     214       0      0  68.636  68.636      61.533       1.000
# 16 Sidechain Chi_3 dihedral restraints:      84       0      0  71.900  71.900      52.923       1.000
# 17 Sidechain Chi_4 dihedral restraints:      32       0      0  94.646  94.646      25.180       1.000
# 18 Disulfide distance restraints      :       0       0      0   0.000   0.000      0.0000       1.000
# 19 Disulfide angle restraints         :       0       0      0   0.000   0.000      0.0000       1.000
# 20 Disulfide dihedral angle restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 21 Lower bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 22 Upper bound distance restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 23 Distance restraints 3 (SDCH-MNCH)  :    3144       0      0   0.345   0.345      60.752       1.000
# 24 Sidechain Chi_5 dihedral restraints:       0       0      0   0.000   0.000      0.0000       1.000
# 25 Phi/Psi pair of dihedral restraints:     333      25     30  24.035  46.815      26.271       1.000
# 26 Distance restraints 4 (SDCH-SDCH)  :    1165       0      0   0.664   0.664      79.396       1.000
# 27 Distance restraints 5 (X-Y)        :       0       0      0   0.000   0.000      0.0000       1.000
# 28 NMR distance restraints 6 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 29 NMR distance restraints 7 (X-Y)    :       0       0      0   0.000   0.000      0.0000       1.000
# 30 Minimal distance restraints        :       0       0      0   0.000   0.000      0.0000       1.000
# 31 Non-bonded restraints              :       0       0      0   0.000   0.000      0.0000       1.000
# 32 Atomic accessibility restraints    :       0       0      0   0.000   0.000      0.0000       1.000
# 33 Atomic density restraints          :       0       0      0   0.000   0.000      0.0000       1.000
# 34 Absolute position restraints       :       0       0      0   0.000   0.000      0.0000       1.000
# 35 Dihedral angle difference restraint:       0       0      0   0.000   0.000      0.0000       1.000
# 36 GBSA implicit solvent potential    :       0       0      0   0.000   0.000      0.0000       1.000
# 37 EM density fitting potential       :       0       0      0   0.000   0.000      0.0000       1.000
# 38 SAXS restraints                    :       0       0      0   0.000   0.000      0.0000       1.000
# 39 Symmetry restraints                :       0       0      0   0.000   0.000      0.0000       1.000
#
#
#
# # Heavy relative violation of each residue is written to: TvLDH.V99990005
# # The profile is NOT normalized by the number of restraints.
# # The profiles are smoothed over a window of residues:    1
# # The sum of all numbers in the file:   30045.2109
#
#
#
# List of the violated restraints:
#    A restraint is violated when the relative difference
#    from the best value (RVIOL) is larger than CUTOFF.
#
#    ICSR   ... index of a restraint in the current set.
#    RESNO  ... residue numbers of the first two atoms.
#    ATM    ... IUPAC atom names of the first two atoms.
#    FEAT   ... the value of the feature in the model.
#    restr  ... the mean of the basis restraint with the smallest
#               difference from the model (local minimum).
#    viol   ... difference from the local minimum.
#    rviol  ... relative difference from the local minimum.
#    RESTR  ... the best value (global minimum).
#    VIOL   ... difference from the best value.
#    RVIOL  ... relative difference from the best value.
#
#
# -------------------------------------------------------------------------------------------------
#
# Feature 25                           : Phi/Psi pair of dihedral restraints
# List of the RVIOL violations larger than   :       6.5000
#
#     #   ICSR  RESNO1/2 ATM1/2   INDATM1/2    FEAT   restr    viol   rviol   RESTR    VIOL   RVIOL
#     1
#    20        274G 274G N   CA   2109 2110  -31.67  -41.20                    8.50
#    21   9452 292D 293K C   N    2248 2250   57.03   56.60    7.42    0.50  -62.90  139.88   24.41
#    21        293K 293K N   CA   2250 2251   31.19   38.60                  -40.80
#    22   9453 293K 294E C   N    2257 2259   46.05   54.60   40.79    2.50  -63.60  164.48   27.65
#    22        294E 294E N   CA   2259 2260   82.29   42.40                  -40.30
#    23   9489 329N 330H C   N    2563 2565  -48.62  -67.60   20.30    1.72  -63.20  171.12   20.52
#    23        330H 330H N   CA   2565 2566  147.20  140.00                  -42.30
#    24   9491 331L 332A C   N    2581 2583  -89.00  -68.20   36.35    3.53  -62.50  158.61   24.83
#    24        332A 332A N   CA   2583 2584  115.49  145.30                  -40.90
#    25   9492 332A 333Q C   N    2586 2588  -60.24  -73.00   26.41    1.53  -63.80  157.92   23.41
#    25        333Q 333Q N   CA   2588 2589  117.58  140.70                  -40.30
#
#
# report______> Distribution of short non-bonded contacts:
#
#
# DISTANCE1:  0.00 2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40
# DISTANCE2:  2.10 2.20 2.30 2.40 2.50 2.60 2.70 2.80 2.90 3.00 3.10 3.20 3.30 3.40 3.50
# FREQUENCY:     0    0    0    0    0   25   30  139  170  269  240  339  414  431  421
#
#
# << end of ENERGY.
#
# >> Summary of successfully produced models:
# Filename                          molpdf     DOPE score    GA341 score
# ----------------------------------------------------------------------
# TvLDH.B99990001.pdb           1757.46753   -37887.17969        1.00000
# TvLDH.B99990002.pdb           1657.36816   -38423.51562        1.00000
# TvLDH.B99990003.pdb           1676.12659   -37810.30859        1.00000
# TvLDH.B99990004.pdb           1680.41357   -37872.63281        1.00000
# TvLDH.B99990005.pdb           1604.15820   -38075.58594        1.00000

# %%
# !python -c 'import pyrosetta_installer; pyrosetta_installer.install_pyrosetta()'
# Out:
# Installing PyRosetta:
#  os: ubuntu
#  type: Release
#  Rosetta C++ extras:
#  mirror: https://west.rosettacommons.org/pyrosetta/release/release
#  extra packages: numpy
#
# PyRosetta wheel url: https://:@west.rosettacommons.org/pyrosetta/release/release/PyRosetta4.Release.python312.ubuntu.wheel/pyrosetta-2024.19+release.a34b73c40f-cp312-cp312-linux_x86_64.whl
# Collecting pyrosetta==2024.19+release.a34b73c40f
#   Downloading https://:****@west.rosettacommons.org/pyrosetta/release/release/PyRosetta4.Release.python312.ubuntu.wheel/pyrosetta-2024.19+release.a34b73c40f-cp312-cp312-linux_x86_64.whl (1668.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 GB 5.2 MB/s eta 0:00:00:00:0100:04m
# Installing collected packages: pyrosetta
# Successfully installed pyrosetta-2024.19+release.a34b73c40f
# Requirement already satisfied: numpy in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (1.26.4)

# %%
# !pip install pyrosetta-distributed
# Out:
# Collecting pyrosetta-distributed
#   Downloading pyrosetta_distributed-0.0.3-py3-none-any.whl.metadata (906 bytes)
# Requirement already satisfied: numpy in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (1.26.4)
# Requirement already satisfied: attrs in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (23.1.0)
# Collecting billiard (from pyrosetta-distributed)
#   Downloading billiard-4.2.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: cloudpickle in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (2.2.1)
# Requirement already satisfied: dask in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (2024.5.0)
# Collecting dask-jobqueue (from pyrosetta-distributed)
#   Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: distributed in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (2024.5.0)
# Requirement already satisfied: gitpython in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (3.1.37)
# Requirement already satisfied: jupyter in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (1.0.0)
# Requirement already satisfied: traitlets in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (5.14.3)
# Collecting blosc (from pyrosetta-distributed)
#   Downloading blosc-1.11.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (16 kB)
# Requirement already satisfied: pandas in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (2.2.2)
# Requirement already satisfied: scipy in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pyrosetta-distributed) (1.13.1)
# Collecting python-xz (from pyrosetta-distributed)
#   Downloading python_xz-0.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: click>=8.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from dask->pyrosetta-distributed) (8.1.7)
# Requirement already satisfied: fsspec>=2021.09.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from dask->pyrosetta-distributed) (2024.3.1)
# Requirement already satisfied: packaging>=20.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from dask->pyrosetta-distributed) (23.2)
# Requirement already satisfied: partd>=1.2.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from dask->pyrosetta-distributed) (1.4.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from dask->pyrosetta-distributed) (6.0.1)
# Requirement already satisfied: toolz>=0.10.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from dask->pyrosetta-distributed) (0.12.0)
# Requirement already satisfied: jinja2>=2.10.3 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (3.1.4)
# Requirement already satisfied: locket>=1.0.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (1.0.3)
# Requirement already satisfied: psutil>=5.7.2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (5.9.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (1.7.0)
# Requirement already satisfied: tornado>=6.0.4 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (6.4.1)
# Requirement already satisfied: urllib3>=1.24.3 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (2.2.2)
# Requirement already satisfied: zict>=3.0.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from distributed->pyrosetta-distributed) (3.0.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from gitpython->pyrosetta-distributed) (4.0.7)
# Requirement already satisfied: notebook in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter->pyrosetta-distributed) (7.0.8)
# Requirement already satisfied: qtconsole in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter->pyrosetta-distributed) (5.5.1)
# Requirement already satisfied: jupyter-console in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter->pyrosetta-distributed) (6.6.3)
# Requirement already satisfied: nbconvert in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter->pyrosetta-distributed) (7.10.0)
# Requirement already satisfied: ipykernel in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter->pyrosetta-distributed) (6.28.0)
# Requirement already satisfied: ipywidgets in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter->pyrosetta-distributed) (7.8.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pandas->pyrosetta-distributed) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pandas->pyrosetta-distributed) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pandas->pyrosetta-distributed) (2023.3)
# Requirement already satisfied: smmap<5,>=3.0.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython->pyrosetta-distributed) (4.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jinja2>=2.10.3->distributed->pyrosetta-distributed) (2.1.3)
# Requirement already satisfied: six>=1.5 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->pyrosetta-distributed) (1.16.0)
# Requirement already satisfied: comm>=0.1.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (8.25.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (0.1.6)
# Requirement already satisfied: nest-asyncio in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (1.6.0)
# Requirement already satisfied: pyzmq>=24 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipykernel->jupyter->pyrosetta-distributed) (25.1.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipywidgets->jupyter->pyrosetta-distributed) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.6 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipywidgets->jupyter->pyrosetta-distributed) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipywidgets->jupyter->pyrosetta-distributed) (1.0.0)
# Requirement already satisfied: prompt-toolkit>=3.0.30 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-console->jupyter->pyrosetta-distributed) (3.0.43)
# Requirement already satisfied: pygments in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-console->jupyter->pyrosetta-distributed) (2.15.1)
# Requirement already satisfied: beautifulsoup4 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (4.1.0)
# Requirement already satisfied: defusedxml in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (0.8.0)
# Requirement already satisfied: nbformat>=5.7 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (5.9.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (1.5.0)
# Requirement already satisfied: tinycss2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbconvert->jupyter->pyrosetta-distributed) (1.2.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->pyrosetta-distributed) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->pyrosetta-distributed) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->pyrosetta-distributed) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from notebook->jupyter->pyrosetta-distributed) (0.2.3)
# Requirement already satisfied: qtpy>=2.4.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from qtconsole->jupyter->pyrosetta-distributed) (2.4.1)
# Requirement already satisfied: webencodings in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert->jupyter->pyrosetta-distributed) (0.5.1)
# Requirement already satisfied: decorator in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (0.18.1)
# Requirement already satisfied: stack-data in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (4.8.0)
# Requirement already satisfied: platformdirs>=2.5 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter->pyrosetta-distributed) (3.10.0)
# Requirement already satisfied: anyio>=3.1.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (21.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (0.4.4)
# Requirement already satisfied: overrides>=5.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (0.14.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->pyrosetta-distributed) (2.0.4)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.1,>=4.0.2->notebook->jupyter->pyrosetta-distributed) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (4.19.2)
# Requirement already satisfied: requests>=2.31 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (2.32.2)
# Requirement already satisfied: fastjsonschema in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->pyrosetta-distributed) (2.16.2)
# Requirement already satisfied: wcwidth in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from prompt-toolkit>=3.0.30->jupyter-console->jupyter->pyrosetta-distributed) (0.2.5)
# Requirement already satisfied: soupsieve>1.2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->pyrosetta-distributed) (2.5)
# Requirement already satisfied: idna>=2.8 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (3.7)
# Requirement already satisfied: sniffio>=1.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (21.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (0.8.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (0.10.6)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (0.1.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (0.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook->jupyter->pyrosetta-distributed) (2024.7.4)
# Requirement already satisfied: executing in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (0.8.3)
# Requirement already satisfied: asttokens in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (2.0.5)
# Requirement already satisfied: pure-eval in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel->jupyter->pyrosetta-distributed) (0.2.2)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Collecting isoduration (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed)
#   Downloading isoduration-20.11.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: jsonpointer>1.13 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=1.11 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed)
#   Downloading webcolors-24.8.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (1.16.0)
# Requirement already satisfied: pycparser in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/prittam-goswami/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook->jupyter->pyrosetta-distributed) (1.2.3)
# Downloading pyrosetta_distributed-0.0.3-py3-none-any.whl (1.6 kB)
# Downloading billiard-4.2.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 6.3 MB/s eta 0:00:00
# Downloading blosc-1.11.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 6.5 MB/s eta 0:00:00a 0:00:01m
# Downloading dask_jobqueue-0.9.0-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 7.5 MB/s eta 0:00:00
# Downloading python_xz-0.5.0-py3-none-any.whl (20 kB)
# Downloading webcolors-24.8.0-py3-none-any.whl (15 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: webcolors, uri-template, python-xz, fqdn, blosc, billiard, isoduration, dask-jobqueue, pyrosetta-distributed
# Successfully installed billiard-4.2.0 blosc-1.11.2 dask-jobqueue-0.9.0 fqdn-1.5.1 isoduration-20.11.0 pyrosetta-distributed-0.0.3 python-xz-0.5.0 uri-template-1.3.0 webcolors-24.8.0

# %%
import pyrosetta

# Initialize PyRosetta
# Initialize PyRosetta with multithreading support
pyrosetta.init()

# Load the docked complex into PyRosetta
pose = pyrosetta.pose_from_pdb('6m0j.pdb')

# Create a MoveMap object to specify which parts of the structure can move
movemap = pyrosetta.rosetta.core.kinematics.MoveMap()
movemap.set_bb(True)  # Allow backbone minimization
movemap.set_chi(True)  # Allow side-chain minimization

# Create and configure the MinMover
scorefxn = pyrosetta.get_fa_scorefxn()  # Get the full-atom score function
min_mover = pyrosetta.rosetta.protocols.minimization_packing.MinMover()
min_mover.movemap(movemap)  # Apply the MoveMap to the MinMover
min_mover.score_function(scorefxn)  # Set the score function
min_mover.max_iter(5000)  # Set the number of minimization iterations

# Apply the minimization
min_mover.apply(pose)


# Calculate the total energy of the minimized complex
total_energy = scorefxn(pose)
print(f"Total Energy after minimization: {total_energy} REU")
# Out:
# ┌──────────────────────────────────────────────────────────────────────────────┐
# │                                 PyRosetta-4                                  │
# │              Created in JHU by Sergey Lyskov and PyRosetta Team              │
# │              (C) Copyright Rosetta Commons Member Institutions               │
# │                                                                              │
# │ NOTE: USE OF PyRosetta FOR COMMERCIAL PURPOSES REQUIRE PURCHASE OF A LICENSE │
# │         See LICENSE.PyRosetta.md or email license@uw.edu for details         │
# └──────────────────────────────────────────────────────────────────────────────┘
# PyRosetta-4 2024 [Rosetta PyRosetta4.Release.python312.ubuntu 2024.19+release.a34b73c40fe9c61558d566d6a63f803cfb15a4fc 2024-05-02T16:22:03] retrieved from: http://www.pyrosetta.org
# core.init: Checking for fconfig files in pwd and ./rosetta/flags
# core.init: Rosetta version: PyRosetta4.Release.python312.ubuntu r381 2024.19+release.a34b73c40f a34b73c40fe9c61558d566d6a63f803cfb15a4fc http://www.pyrosetta.org 2024-05-02T16:22:03
# core.init: Rosetta extras: []
# core.init: command: PyRosetta -ex1 -ex2aro -database /home/prittam-goswami/anaconda3/lib/python3.12/site-packages/pyrosetta/database
# basic.random.init_random_generator: 'RNG device' seed mode, using '/dev/urandom', seed=-1367874384 seed_offset=0 real_seed=-1367874384
# basic.random.init_random_generator: RandomGenerator:init: Normal mode, seed=-1367874384 RG_type=mt19937
# core.import_pose.import_pose: File '6m0j.pdb' automatically determined to be of type PDB
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ASP:CtermProteinFull 597
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 600
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 601
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 602
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 603
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLY:CtermProteinFull 797
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 798
# core.conformation.Conformation: Found disulfide between residues 115 123
# core.conformation.Conformation: Found disulfide between residues 326 343
# core.conformation.Conformation: Found disulfide between residues 512 524
# core.conformation.Conformation: Found disulfide between residues 607 632
# core.conformation.Conformation: Found disulfide between residues 650 703
# core.conformation.Conformation: Found disulfide between residues 662 796
# core.conformation.Conformation: Found disulfide between residues 751 759
# core.pack.pack_missing_sidechains: packing residue number 600 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 601 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 602 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 603 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 798 because of missing atom number 10 atom name O1
# core.pack.task: Packer task: initialize from command line()
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.pack_rotamers: built 5 rotamers at 5 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.optimization.Minimizer: [ WARNING ] LBFGS MAX CYCLES 5000 EXCEEDED, BUT FUNC NOT CONVERGED!
# Total Energy after minimization: -2187.9494868767338 REU

# %%
1736.1101167092763

# %%
# Load the complex into PyRosetta
pose_complex = pyrosetta.pose_from_pdb('6m0j.pdb')

# Separate the complex into receptor and ligand (you will need to specify the chain IDs)
# Assuming chain A is the receptor and chain B is the ligand
pose_receptor = pose_complex.split_by_chain(1)  # Receptor
pose_ligand = pose_complex.split_by_chain(2)    # Ligand

# Get the score function
scorefxn = pyrosetta.get_fa_scorefxn()

# Calculate energies
energy_complex = scorefxn(pose_complex)
energy_receptor = scorefxn(pose_receptor)
energy_ligand = scorefxn(pose_ligand)

# Calculate the binding affinity (ΔG)
binding_affinity = energy_complex - (energy_receptor + energy_ligand)
print(f"Binding Affinity (ΔG): {binding_affinity} REU")
# Out:
# core.import_pose.import_pose: File '6m0j.pdb' automatically determined to be of type PDB
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue ASP:CtermProteinFull 597
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 600
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 601
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 602
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 603
# core.conformation.Conformation: [ WARNING ] missing heavyatom:  OXT on residue GLY:CtermProteinFull 797
# core.conformation.Conformation: [ WARNING ] missing heavyatom: O1 on residue pdb_NAG 798
# core.conformation.Conformation: Found disulfide between residues 115 123
# core.conformation.Conformation: Found disulfide between residues 326 343
# core.conformation.Conformation: Found disulfide between residues 512 524
# core.conformation.Conformation: Found disulfide between residues 607 632
# core.conformation.Conformation: Found disulfide between residues 650 703
# core.conformation.Conformation: Found disulfide between residues 662 796
# core.conformation.Conformation: Found disulfide between residues 751 759
# core.pack.pack_missing_sidechains: packing residue number 600 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 601 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 602 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 603 because of missing atom number 10 atom name O1
# core.pack.pack_missing_sidechains: packing residue number 798 because of missing atom number 10 atom name O1
# core.pack.task: Packer task: initialize from command line()
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.rotamer_set.RotamerSet_: Using simple Rotamer generation logic for pdb_NAG
# core.pack.pack_rotamers: built 5 rotamers at 5 positions.
# core.pack.interaction_graph.interaction_graph_factory: Instantiating DensePDInteractionGraph
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 1
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 8 to 1
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 2
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 7 to 2
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 3
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 6 to 3
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 4
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 5 to 4
# core.conformation.Conformation: Found disulfide between residues 115 123
# core.conformation.Conformation: Found disulfide between residues 326 343
# core.conformation.Conformation: Found disulfide between residues 512 524
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 1
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 8 to 1
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 2
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 7 to 2
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 3
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 6 to 3
# core.kinematics.FoldTree: delete_jump_seqpos: deleting jump 4
# core.kinematics.FoldTree: delete_jump_seqpos: renumbering jump 5 to 4
# core.scoring.ScoreFunctionFactory: SCOREFUNCTION: ref2015
# Binding Affinity (ΔG): 4426.44769380744 REU
